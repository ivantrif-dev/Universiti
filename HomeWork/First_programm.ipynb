# %% [markdown]
# <a href="https://colab.research.google.com/github/ivantrif-dev/Universiti/blob/main/Tasks/First_programm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World! HELP!')
# Out:
# Hello World!
